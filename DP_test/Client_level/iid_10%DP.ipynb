# %%
epochs = 1
n_train_items = 6000
rounds = 200
total_client = 100
C = 0.1
n_workers = int(total_client * C)
batch_size = 50

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import random
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import syft as sy  # <-- NEW: import the Pysyft library
hook = sy.TorchHook(torch)  # <-- NEW: hook PyTorch ie add extra functionalities to support Federated Learning
# simulation functions
def connect_to_workers(n_workers):
    return [
        sy.VirtualWorker(hook, id=f"worker{i+1}")
        for i in range(n_workers)
    ]


workers = connect_to_workers(n_workers=n_workers)
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:469: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:470: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:471: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:472: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:473: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:476: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
class Arguments():
    def __init__(self):
        self.batch_size = batch_size
        self.test_batch_size = 60
        self.epochs = epochs
        self.rounds = rounds
        self.lr = 0.02
        self.momentum = 0.5
        self.no_cuda = False
        self.seed = 1
        self.log_interval = 2
        self.save_model = False
        self.n_train_items = n_train_items

args = Arguments()

use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
# federated_train_loader = sy.FederatedDataLoader( # <-- this is now a FederatedDataLoader 
#     datasets.MNIST('../data', train=True, download=True,
#                    transform=transforms.Compose([
#                        transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
#                    ]))
#     .federate(workers), # <-- NEW: we distribute the dataset across all the workers, it's now a FederatedDataset
#     batch_size=args.batch_size, shuffle=True, **kwargs)

# test_loader = torch.utils.data.DataLoader(
#     datasets.MNIST('../data', train=False, transform=transforms.Compose([
#                        transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
#                    ])),
#     batch_size=args.test_batch_size, shuffle=True, **kwargs)

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('/root/notebooks/data/', train=True, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.batch_size
)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('/root/notebooks/data/', train=False, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.test_batch_size
)

    
#---

# less_train_dataloader = [
#         ((data), (target))
#         for i, (data, target) in enumerate(train_loader)
#         if i < (n_train_items / args.batch_size) * 10
#     ]

# %%
print(len(train_loader))
# print(len(less_train_dataloader))
# Out:
# 1200

# %%
# from PIL import Image
# import numpy 
# #mnist_dataset.__getitem__(2)[1]
# a = (mnist_dataset.__getitem__(0)[0]).numpy()
# a.dtype = 'uint8'
# print(a)
# Image.fromarray(a[0], mode= 'P')

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5, 1)
        self.conv2 = nn.Conv2d(32, 64, 5, 1)
        self.fc1 = nn.Linear(4*4*64, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*64)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def model_init(workers, Net):
    model_list = list()
    for worker in workers:
        model_list.append(Net)
    return model_list
def opt_init(model_list):
    opt_list = list()
    for model  in model_list:
        opt_list.append(optim.SGD(model.parameters(), lr=args.lr))
    return opt_list
def random_sample(train_dataloader):
    choice_list = sorted(random.sample(range(100), 10))
    count = 0
    tmp = []
    for i, data in enumerate(train_dataloader):
        if  i == choice_list[count]:
            tmp.append(data)
            if count == 9:
                pass
            else:
                count += 1
    return tmp

# %%
def train(args, device, train_loader, opt_list, workers):
    global model_list
    ## start training and record the model into model_list
    
    less_train_dataloader = random_sample(train_loader)
    for epoch in range(args.epochs):
        for batch_idx, (data, target) in enumerate(less_train_dataloader): # <-- now it is a distributed dataset
            model_on_worker = model_list[batch_idx%len(workers)]
            model_on_worker.train()
            model_on_worker.send(workers[batch_idx%len(workers)]) # <-- NEW: send the model to the right location

            data_on_worker = data.send(workers[batch_idx%len(workers)])
            target_on_worker = target.send(workers[batch_idx%len(workers)])

            data_on_worker, target_on_worker = data_on_worker.to(device), target_on_worker.to(device)

            opt_list[batch_idx%len(workers)].zero_grad()

            output = model_on_worker(data_on_worker)
            loss = F.nll_loss(output, target_on_worker)
            loss.backward()

            opt_list[batch_idx%len(workers)].step()
            model_on_worker.get() # <-- NEW: get the model back

            model_list[batch_idx%len(workers)] = model_on_worker #When len(dataloader) is longer than the len(worker) send and get must be modified
            #model_list here is full of the model which has trained on the workers, there are all different now.

        if epoch % args.log_interval == 0:
            loss = loss.get() # <-- NEW: get the loss back
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, n_train_items, n_train_items ,
                100. * epoch / args.epochs, loss.item()))


    ##Aggregation time
    new_model = []
    tmp_model = Net().to(device)
    with torch.no_grad():
        for p in model_list[0].parameters():
            new_model.append(0)
            
        for m in model_list:
            for par_idx, par in enumerate(m.parameters()):
                #average the model_list
                new_model[par_idx] = new_model[par_idx]+par.data
                # we get new model in list format and need to set_ to model
        
        for n in new_model:
            n.add_(torch.normal(0,4*1.5,n.size(),device=device)*args.lr)
        
        for worker in range(len(workers)):
            for par_idx in range(len(new_model)):
                list(model_list[worker].parameters())[par_idx].set_(new_model[par_idx]/len(workers))
        #init model with new_model

# %%
def test(args, model, device, test_loader, r):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader)*(args.test_batch_size)
    accuracy = 100. * correct / (len(test_loader)*args.test_batch_size)
    #Since the test loader here is a list, we can get the len by * it with batch.size
    
    
    writer.add_scalar('Accuracy', accuracy,r)
    writer.add_scalar('Loss', test_loss, r)
    print('\nTest set in round{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        r , test_loss, correct, len(test_loader)* (args.test_batch_size),
        accuracy))

# %%
from dpfl import accountant
from dpfl.accountant import GaussianMomentsAccountant

# %%
Acc = GaussianMomentsAccountant
print(Acc)
# Out:
# <class 'dpfl.accountant.GaussianMomentsAccountant'>

# %%
x, y = 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-e6963cc27b3f> in <module>
# ----> 1 x, y = 0
#
# TypeError: 'int' object is not iterable

# %%
# %%time
#optimizer = optim.SGD(model.parameters(), lr=args.lr) # TODO momentum is not supported at the moment
logdir = '/root/notebooks/tensorflow/logs/Client_level/DP_s4/'
writer = SummaryWriter(logdir)

model_list = []
model_list = model_init(workers, Net().to(device))
opt_list = opt_init(model_list)
# not finish in train, finish latter
pars = [list(model.parameters()) for model in model_list]

for r in range(1, args.rounds + 1):
    train(args, device, train_loader, opt_list, workers)
    print("After training")
    test(args, model_list[0], device, test_loader, r)


if (args.save_model):
    torch.save(model.state_dict(), "mnist_cnn.pt")
# Out:
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 2.143909
# After training
#
# Test set in round1: Average loss: 2.2455, Accuracy: 2056/10020 (20.52%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 2.075596
# After training
#
# Test set in round2: Average loss: 2.1174, Accuracy: 2213/10020 (22.09%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 1.803790
# After training
#
# Test set in round3: Average loss: 1.8067, Accuracy: 6126/10020 (61.14%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 1.198592
# After training
#
# Test set in round4: Average loss: 1.3721, Accuracy: 6772/10020 (67.58%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.939189
# After training
#
# Test set in round5: Average loss: 1.0235, Accuracy: 7556/10020 (75.41%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.807317
# After training
#
# Test set in round6: Average loss: 0.7832, Accuracy: 7489/10020 (74.74%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.682450
# After training
#
# Test set in round7: Average loss: 0.6037, Accuracy: 8303/10020 (82.86%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.716649
# After training
#
# Test set in round8: Average loss: 0.8573, Accuracy: 7209/10020 (71.95%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.558238
# After training
#
# Test set in round9: Average loss: 0.5074, Accuracy: 8462/10020 (84.45%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.219478
# After training
#
# Test set in round10: Average loss: 0.5349, Accuracy: 8335/10020 (83.18%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.535496
# After training
#
# Test set in round11: Average loss: 0.4679, Accuracy: 8509/10020 (84.92%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.838723
# After training
#
# Test set in round12: Average loss: 0.7663, Accuracy: 7517/10020 (75.02%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.362927
# After training
#
# Test set in round13: Average loss: 0.4052, Accuracy: 8753/10020 (87.36%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.537344
# After training
#
# Test set in round14: Average loss: 0.5259, Accuracy: 8296/10020 (82.79%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.264593
# After training
#
# Test set in round15: Average loss: 0.3598, Accuracy: 8859/10020 (88.41%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.444184
# After training
#
# Test set in round16: Average loss: 0.4650, Accuracy: 8398/10020 (83.81%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.314100
# After training
#
# Test set in round17: Average loss: 0.3140, Accuracy: 9052/10020 (90.34%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.243865
# After training
#
# Test set in round18: Average loss: 0.3957, Accuracy: 8727/10020 (87.10%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.264234
# After training
#
# Test set in round19: Average loss: 0.3061, Accuracy: 9058/10020 (90.40%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.317119
# After training
#
# Test set in round20: Average loss: 0.3031, Accuracy: 9017/10020 (89.99%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.531048
# After training
#
# Test set in round21: Average loss: 0.8063, Accuracy: 8156/10020 (81.40%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.206977
# After training
#
# Test set in round22: Average loss: 0.3655, Accuracy: 8836/10020 (88.18%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.302576
# After training
#
# Test set in round23: Average loss: 0.4924, Accuracy: 8402/10020 (83.85%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.310065
# After training
#
# Test set in round24: Average loss: 0.3420, Accuracy: 8974/10020 (89.56%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.307418
# After training
#
# Test set in round25: Average loss: 0.4178, Accuracy: 8710/10020 (86.93%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.162437
# After training
#
# Test set in round26: Average loss: 0.3591, Accuracy: 8883/10020 (88.65%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.042221
# After training
#
# Test set in round27: Average loss: 0.2634, Accuracy: 9129/10020 (91.11%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.283111
# After training
#
# Test set in round28: Average loss: 0.3205, Accuracy: 8965/10020 (89.47%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.048597
# After training
#
# Test set in round29: Average loss: 0.2775, Accuracy: 9152/10020 (91.34%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.070474
# After training
#
# Test set in round30: Average loss: 0.2449, Accuracy: 9240/10020 (92.22%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.216913
# After training
#
# Test set in round31: Average loss: 0.3355, Accuracy: 8924/10020 (89.06%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.213042
# After training
#
# Test set in round32: Average loss: 0.2920, Accuracy: 9120/10020 (91.02%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.312620
# After training
#
# Test set in round33: Average loss: 0.3223, Accuracy: 9009/10020 (89.91%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.073628
# After training
#
# Test set in round34: Average loss: 0.3416, Accuracy: 9014/10020 (89.96%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.204061
# After training
#
# Test set in round35: Average loss: 0.3156, Accuracy: 9035/10020 (90.17%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.097513
# After training
#
# Test set in round36: Average loss: 0.2788, Accuracy: 9153/10020 (91.35%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.164686
# After training
#
# Test set in round37: Average loss: 0.3229, Accuracy: 9029/10020 (90.11%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.073570
# After training
#
# Test set in round38: Average loss: 0.3447, Accuracy: 9005/10020 (89.87%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.076158
# After training
#
# Test set in round39: Average loss: 0.3230, Accuracy: 9038/10020 (90.20%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.227316
# After training
#
# Test set in round40: Average loss: 0.3267, Accuracy: 9072/10020 (90.54%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.378130
# After training
#
# Test set in round41: Average loss: 0.4038, Accuracy: 8854/10020 (88.36%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.220635
# After training
#
# Test set in round42: Average loss: 0.3328, Accuracy: 9001/10020 (89.83%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.281997
# After training
#
# Test set in round43: Average loss: 0.3672, Accuracy: 8913/10020 (88.95%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.238896
# After training
#
# Test set in round44: Average loss: 0.3272, Accuracy: 9049/10020 (90.31%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.140233
# After training
#
# Test set in round45: Average loss: 0.3581, Accuracy: 8944/10020 (89.26%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.159101
# After training
#
# Test set in round46: Average loss: 0.2625, Accuracy: 9206/10020 (91.88%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.267241
# After training
#
# Test set in round47: Average loss: 0.3104, Accuracy: 9072/10020 (90.54%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.825338
# After training
#
# Test set in round48: Average loss: 0.4032, Accuracy: 8897/10020 (88.79%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.195593
# After training
#
# Test set in round49: Average loss: 0.3026, Accuracy: 9131/10020 (91.13%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.264392
# After training
#
# Test set in round50: Average loss: 0.4615, Accuracy: 8670/10020 (86.53%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.057727
# After training
#
# Test set in round51: Average loss: 0.3243, Accuracy: 9081/10020 (90.63%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.316675
# After training
#
# Test set in round52: Average loss: 0.5332, Accuracy: 8532/10020 (85.15%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.338242
# After training
#
# Test set in round53: Average loss: 0.6909, Accuracy: 8450/10020 (84.33%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.260464
# After training
#
# Test set in round54: Average loss: 0.3257, Accuracy: 9097/10020 (90.79%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.041366
# After training
#
# Test set in round55: Average loss: 0.2841, Accuracy: 9180/10020 (91.62%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.063218
# After training
#
# Test set in round56: Average loss: 0.3407, Accuracy: 9103/10020 (90.85%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.623794
# After training
#
# Test set in round57: Average loss: 0.4703, Accuracy: 8861/10020 (88.43%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.264980
# After training
#
# Test set in round58: Average loss: 0.3548, Accuracy: 9070/10020 (90.52%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.133052
# After training
#
# Test set in round59: Average loss: 0.2856, Accuracy: 9210/10020 (91.92%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.170899
# After training
#
# Test set in round60: Average loss: 0.3074, Accuracy: 9191/10020 (91.73%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.165346
# After training
#
# Test set in round61: Average loss: 0.3172, Accuracy: 9164/10020 (91.46%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.530246
# After training
#
# Test set in round62: Average loss: 0.4457, Accuracy: 8911/10020 (88.93%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.184907
# After training
#
# Test set in round63: Average loss: 0.3404, Accuracy: 9189/10020 (91.71%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.014322
# After training
#
# Test set in round64: Average loss: 0.3145, Accuracy: 9240/10020 (92.22%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.117738
# After training
#
# Test set in round65: Average loss: 0.3296, Accuracy: 9160/10020 (91.42%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.230330
# After training
#
# Test set in round66: Average loss: 0.3343, Accuracy: 9189/10020 (91.71%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.807327
# After training
#
# Test set in round67: Average loss: 0.5936, Accuracy: 8647/10020 (86.30%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.249230
# After training
#
# Test set in round68: Average loss: 0.2888, Accuracy: 9308/10020 (92.89%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.009556
# After training
#
# Test set in round69: Average loss: 0.2951, Accuracy: 9275/10020 (92.56%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.197545
# After training
#
# Test set in round70: Average loss: 0.3930, Accuracy: 9140/10020 (91.22%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.223310
# After training
#
# Test set in round71: Average loss: 0.4625, Accuracy: 8928/10020 (89.10%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.276619
# After training
#
# Test set in round72: Average loss: 0.6385, Accuracy: 8693/10020 (86.76%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.105012
# After training
#
# Test set in round73: Average loss: 0.3342, Accuracy: 9245/10020 (92.27%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.139337
# After training
#
# Test set in round74: Average loss: 0.3099, Accuracy: 9280/10020 (92.61%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.219272
# After training
#
# Test set in round75: Average loss: 0.3453, Accuracy: 9249/10020 (92.31%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.236867
# After training
#
# Test set in round76: Average loss: 0.3641, Accuracy: 9142/10020 (91.24%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.370695
# After training
#
# Test set in round77: Average loss: 0.4106, Accuracy: 9069/10020 (90.51%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.123483
# After training
#
# Test set in round78: Average loss: 0.3411, Accuracy: 9245/10020 (92.27%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.447525
# After training
#
# Test set in round79: Average loss: 0.3346, Accuracy: 9236/10020 (92.18%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.037659
# After training
#
# Test set in round80: Average loss: 0.3468, Accuracy: 9257/10020 (92.39%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.122139
# After training
#
# Test set in round81: Average loss: 0.3727, Accuracy: 9192/10020 (91.74%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.098903
# After training
#
# Test set in round82: Average loss: 0.3628, Accuracy: 9210/10020 (91.92%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.300479
# After training
#
# Test set in round83: Average loss: 0.3738, Accuracy: 9196/10020 (91.78%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.094135
# After training
#
# Test set in round84: Average loss: 0.3064, Accuracy: 9326/10020 (93.07%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.164653
# After training
#
# Test set in round85: Average loss: 0.3807, Accuracy: 9187/10020 (91.69%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.074657
# After training
#
# Test set in round86: Average loss: 0.3632, Accuracy: 9224/10020 (92.06%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.243014
# After training
#
# Test set in round87: Average loss: 0.5948, Accuracy: 8834/10020 (88.16%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.134442
# After training
#
# Test set in round88: Average loss: 0.3895, Accuracy: 9188/10020 (91.70%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.131142
# After training
#
# Test set in round89: Average loss: 0.5269, Accuracy: 9053/10020 (90.35%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.278928
# After training
#
# Test set in round90: Average loss: 0.3379, Accuracy: 9322/10020 (93.03%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.388442
# After training
#
# Test set in round91: Average loss: 0.3343, Accuracy: 9363/10020 (93.44%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 1.061050
# After training
#
# Test set in round92: Average loss: 0.4128, Accuracy: 9196/10020 (91.78%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.273055
# After training
#
# Test set in round93: Average loss: 0.3829, Accuracy: 9286/10020 (92.67%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.390043
# After training
#
# Test set in round94: Average loss: 0.4986, Accuracy: 9113/10020 (90.95%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.570095
# After training
#
# Test set in round95: Average loss: 0.4666, Accuracy: 9126/10020 (91.08%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.099530
# After training
#
# Test set in round96: Average loss: 0.3796, Accuracy: 9286/10020 (92.67%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.040976
# After training
#
# Test set in round97: Average loss: 0.4258, Accuracy: 9181/10020 (91.63%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.107712
# After training
#
# Test set in round98: Average loss: 0.3375, Accuracy: 9353/10020 (93.34%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.173293
# After training
#
# Test set in round99: Average loss: 0.3810, Accuracy: 9231/10020 (92.13%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.028304
# After training
#
# Test set in round100: Average loss: 0.4011, Accuracy: 9225/10020 (92.07%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.285546
# After training
#
# Test set in round101: Average loss: 0.4113, Accuracy: 9184/10020 (91.66%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.347341
# After training
#
# Test set in round102: Average loss: 0.4044, Accuracy: 9199/10020 (91.81%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.025925
# After training
#
# Test set in round103: Average loss: 0.4050, Accuracy: 9223/10020 (92.05%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.079698
# After training
#
# Test set in round104: Average loss: 0.3854, Accuracy: 9298/10020 (92.79%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.341472
# After training
#
# Test set in round105: Average loss: 0.4188, Accuracy: 9194/10020 (91.76%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.523058
# After training
#
# Test set in round106: Average loss: 0.4637, Accuracy: 9179/10020 (91.61%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.011481
# After training
#
# Test set in round107: Average loss: 0.3531, Accuracy: 9294/10020 (92.75%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.014679
# After training
#
# Test set in round108: Average loss: 0.3353, Accuracy: 9346/10020 (93.27%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.001653
# After training
#
# Test set in round109: Average loss: 0.5169, Accuracy: 9005/10020 (89.87%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.011973
# After training
#
# Test set in round110: Average loss: 0.4475, Accuracy: 9186/10020 (91.68%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.040541
# After training
#
# Test set in round111: Average loss: 0.4500, Accuracy: 9258/10020 (92.40%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.271599
# After training
#
# Test set in round112: Average loss: 0.5135, Accuracy: 9170/10020 (91.52%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.043420
# After training
#
# Test set in round113: Average loss: 0.6528, Accuracy: 8966/10020 (89.48%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.014935
# After training
#
# Test set in round114: Average loss: 0.4607, Accuracy: 9203/10020 (91.85%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.210401
# After training
#
# Test set in round115: Average loss: 0.9550, Accuracy: 8624/10020 (86.07%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.153791
# After training
#
# Test set in round116: Average loss: 0.4074, Accuracy: 9270/10020 (92.51%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.022972
# After training
#
# Test set in round117: Average loss: 0.4157, Accuracy: 9282/10020 (92.63%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.045355
# After training
#
# Test set in round118: Average loss: 0.4232, Accuracy: 9285/10020 (92.66%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.022951
# After training
#
# Test set in round119: Average loss: 0.4738, Accuracy: 9247/10020 (92.29%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.147574
# After training
#
# Test set in round120: Average loss: 0.5057, Accuracy: 9186/10020 (91.68%)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-14-7bea6873e23f> in train(args, device, train_loader, opt_list, workers)
#       3     ## start training and record the model into model_list
#       4
# ----> 5     less_train_dataloader = random_sample(train_loader)
#       6     for epoch in range(args.epochs):
#       7         for batch_idx, (data, target) in enumerate(less_train_dataloader): # <-- now it is a distributed dataset
#
# <ipython-input-10-ecc68eea67b4> in random_sample(train_dataloader)
#      13     count = 0
#      14     tmp = []
# ---> 15     for i, data in enumerate(train_dataloader):
#      16         if  i == choice_list[count]:
#      17             tmp.append(data)
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /opt/conda/lib/python3.6/site-packages/torchvision/datasets/mnist.py in __getitem__(self, index)
#      80         self.data, self.targets = torch.load(os.path.join(self.processed_folder, data_file))
#      81
# ---> 82     def __getitem__(self, index):
#      83         """
#      84         Args:
#
# KeyboardInterrupt:
