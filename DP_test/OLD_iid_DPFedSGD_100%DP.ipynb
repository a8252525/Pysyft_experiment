# %%
epochs = 1
n_train_items = 6000
rounds = 650
total_client = 100
C = 0.1
n_workers = int(total_client * C)
batch_size = 600

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import random
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import syft as sy  # <-- NEW: import the Pysyft library
hook = sy.TorchHook(torch)  # <-- NEW: hook PyTorch ie add extra functionalities to support Federated Learning
# simulation functions
def connect_to_workers(n_workers):
    return [
        sy.VirtualWorker(hook, id=f"worker{i+1}")
        for i in range(n_workers)
    ]


workers = connect_to_workers(n_workers=n_workers)
# Out:
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class Arguments():
    def __init__(self):
        self.batch_size = batch_size
        self.test_batch_size = 60
        self.epochs = epochs
        self.rounds = rounds
        self.lr = 0.02
        self.momentum = 0.5
        self.no_cuda = False
        self.seed = 1
        self.log_interval = 2
        self.save_model = False
        self.n_train_items = n_train_items

args = Arguments()

use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# %%
# federated_train_loader = sy.FederatedDataLoader( # <-- this is now a FederatedDataLoader 
#     datasets.MNIST('../data', train=True, download=True,
#                    transform=transforms.Compose([
#                        transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
#                    ]))
#     .federate(workers), # <-- NEW: we distribute the dataset across all the workers, it's now a FederatedDataset
#     batch_size=args.batch_size, shuffle=True, **kwargs)

# test_loader = torch.utils.data.DataLoader(
#     datasets.MNIST('../data', train=False, transform=transforms.Compose([
#                        transforms.ToTensor(),
#                        transforms.Normalize((0.1307,), (0.3081,))
#                    ])),
#     batch_size=args.test_batch_size, shuffle=True, **kwargs)

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=True, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.batch_size
)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=False, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.test_batch_size
)

    
#---

# less_train_dataloader = [
#         ((data), (target))
#         for i, (data, target) in enumerate(train_loader)
#         if i < (n_train_items / args.batch_size) * 10
#     ]

# %%
print(len(train_loader))
# print(len(less_train_dataloader))
# Out:
# 100

# %%
# from PIL import Image
# import numpy 
# #mnist_dataset.__getitem__(2)[1]
# a = (mnist_dataset.__getitem__(0)[0]).numpy()
# a.dtype = 'uint8'
# print(a)
# Image.fromarray(a[0], mode= 'P')

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5, 1)
        self.conv2 = nn.Conv2d(32, 64, 5, 1)
        self.fc1 = nn.Linear(4*4*64, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4*4*64)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
def model_init(workers, Net):
    model_list = list()
    for worker in workers:
        model_list.append(Net)
    return model_list
def opt_init(model_list):
    opt_list = list()
    for model  in model_list:
        opt_list.append(optim.SGD(model.parameters(), lr=args.lr))
    return opt_list
def random_sample(train_dataloader):
    choice_list = sorted(random.sample(range(100), 10))
    count = 0
    tmp = []
    for i, data in enumerate(train_dataloader):
        if  i == choice_list[count]:
            tmp.append(data)
            if count == 9:
                pass
            else:
                count += 1
    return tmp

# %%
def train(args, device, train_loader, opt_list, workers):
    global model_list
    ## start training and record the model into model_list
    
    less_train_dataloader = random_sample(train_loader)
    for epoch in range(args.epochs):
        for batch_idx, (data, target) in enumerate(less_train_dataloader): # <-- now it is a distributed dataset
            model_on_worker = model_list[batch_idx%len(workers)]
            model_on_worker.train()
            model_on_worker.send(workers[batch_idx%len(workers)]) # <-- NEW: send the model to the right location

            data_on_worker = data.send(workers[batch_idx%len(workers)])
            target_on_worker = target.send(workers[batch_idx%len(workers)])

            data_on_worker, target_on_worker = data_on_worker.to(device), target_on_worker.to(device)

            opt_list[batch_idx%len(workers)].zero_grad()

            output = model_on_worker(data_on_worker)
            loss = F.nll_loss(output, target_on_worker)
            loss.backward()

            opt_list[batch_idx%len(workers)].step()
            model_on_worker.get() # <-- NEW: get the model back

            model_list[batch_idx%len(workers)] = model_on_worker #When len(dataloader) is longer than the len(worker) send and get must be modified
            #model_list here is full of the model which has trained on the workers, there are all different now.

        if epoch % args.log_interval == 0:
            loss = loss.get() # <-- NEW: get the loss back
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, n_train_items, n_train_items ,
                100. * epoch / args.epochs, loss.item()))


    ##Aggregation time
    new_model = []
    tmp_model = Net().to(device)
    with torch.no_grad():
        for p in model_list[0].parameters():
            new_model.append(0)
            
        for m in model_list:
            for par_idx, par in enumerate(m.parameters()):
                #average the model_list
                new_model[par_idx] = new_model[par_idx]+par.data
                # we get new model in list format and need to set_ to model
        
        for i in range(10):
            for n in new_model:
                n.add_(torch.normal(0,1.3*1.5,n.size(),device=device)*args.lr/args.batch_size)
        
        for worker in range(len(workers)):
            for par_idx in range(len(new_model)):
                list(model_list[worker].parameters())[par_idx].set_(new_model[par_idx]/len(workers))
        #init model with new_model

# %%
def test(args, model, device, test_loader, r):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader)*(args.test_batch_size)
    accuracy = 100. * correct / (len(test_loader)*args.test_batch_size)
    #Since the test loader here is a list, we can get the len by * it with batch.size
    
    
    writer.add_scalar('Accuracy', accuracy,r)
    writer.add_scalar('Loss', test_loss, r)
    print('\nTest set in round{}: Average loss: {:.4f}, Accuracy: {}/{} ({:.2f}%)\n'.format(
        r , test_loss, correct, len(test_loader)* (args.test_batch_size),
        accuracy))

# %%
# %%time
#optimizer = optim.SGD(model.parameters(), lr=args.lr) # TODO momentum is not supported at the moment
logdir = '/root/notebooks/tensorflow/logs/100%DP/'
writer = SummaryWriter(logdir)

model_list = []
model_list = model_init(workers, Net().to(device))
opt_list = opt_init(model_list)
# not finish in train, finish latter
pars = [list(model.parameters()) for model in model_list]

for r in range(1, args.rounds + 1):
    train(args, device, train_loader, opt_list, workers)
    print("After training")
    test(args, model_list[0], device, test_loader, r)


if (args.save_model):
    torch.save(model.state_dict(), "mnist_cnn.pt")
# Out:
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 2.204031
# After training
#
# Test set in round1: Average loss: 2.1838, Accuracy: 4898/10020 (48.88%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 2.045137
# After training
#
# Test set in round2: Average loss: 2.0159, Accuracy: 7243/10020 (72.29%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 1.754454
# After training
#
# Test set in round3: Average loss: 1.7211, Accuracy: 7455/10020 (74.40%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 1.250858
# After training
#
# Test set in round4: Average loss: 1.2682, Accuracy: 7869/10020 (78.53%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.988141
# After training
#
# Test set in round5: Average loss: 0.9033, Accuracy: 7806/10020 (77.90%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.842933
# After training
#
# Test set in round6: Average loss: 0.8960, Accuracy: 6915/10020 (69.01%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.564443
# After training
#
# Test set in round7: Average loss: 0.6099, Accuracy: 8318/10020 (83.01%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.450164
# After training
#
# Test set in round8: Average loss: 0.4978, Accuracy: 8730/10020 (87.13%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.533673
# After training
#
# Test set in round9: Average loss: 0.4554, Accuracy: 8756/10020 (87.39%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.518974
# After training
#
# Test set in round10: Average loss: 0.4697, Accuracy: 8590/10020 (85.73%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.465478
# After training
#
# Test set in round11: Average loss: 0.4490, Accuracy: 8617/10020 (86.00%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.389746
# After training
#
# Test set in round12: Average loss: 0.4065, Accuracy: 8793/10020 (87.75%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.345291
# After training
#
# Test set in round13: Average loss: 0.3616, Accuracy: 8978/10020 (89.60%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.326123
# After training
#
# Test set in round14: Average loss: 0.3518, Accuracy: 8954/10020 (89.36%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.317491
# After training
#
# Test set in round15: Average loss: 0.3126, Accuracy: 9129/10020 (91.11%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.367752
# After training
#
# Test set in round16: Average loss: 0.3329, Accuracy: 8965/10020 (89.47%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.249120
# After training
#
# Test set in round17: Average loss: 0.2771, Accuracy: 9197/10020 (91.79%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.262936
# After training
#
# Test set in round18: Average loss: 0.2733, Accuracy: 9215/10020 (91.97%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.247981
# After training
#
# Test set in round19: Average loss: 0.2614, Accuracy: 9272/10020 (92.53%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.264444
# After training
#
# Test set in round20: Average loss: 0.2766, Accuracy: 9170/10020 (91.52%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.238499
# After training
#
# Test set in round21: Average loss: 0.2494, Accuracy: 9282/10020 (92.63%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.218060
# After training
#
# Test set in round22: Average loss: 0.2410, Accuracy: 9283/10020 (92.64%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.205099
# After training
#
# Test set in round23: Average loss: 0.2351, Accuracy: 9320/10020 (93.01%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.233212
# After training
#
# Test set in round24: Average loss: 0.2376, Accuracy: 9291/10020 (92.72%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.191877
# After training
#
# Test set in round25: Average loss: 0.2173, Accuracy: 9372/10020 (93.53%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.261780
# After training
#
# Test set in round26: Average loss: 0.2303, Accuracy: 9316/10020 (92.97%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.194326
# After training
#
# Test set in round27: Average loss: 0.1998, Accuracy: 9432/10020 (94.13%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.179804
# After training
#
# Test set in round28: Average loss: 0.2003, Accuracy: 9436/10020 (94.17%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.211372
# After training
#
# Test set in round29: Average loss: 0.2029, Accuracy: 9400/10020 (93.81%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.176481
# After training
#
# Test set in round30: Average loss: 0.1950, Accuracy: 9416/10020 (93.97%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.165988
# After training
#
# Test set in round31: Average loss: 0.1877, Accuracy: 9448/10020 (94.29%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.221624
# After training
#
# Test set in round32: Average loss: 0.1864, Accuracy: 9448/10020 (94.29%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.200747
# After training
#
# Test set in round33: Average loss: 0.1921, Accuracy: 9449/10020 (94.30%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.192653
# After training
#
# Test set in round34: Average loss: 0.1811, Accuracy: 9464/10020 (94.45%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.159217
# After training
#
# Test set in round35: Average loss: 0.1674, Accuracy: 9518/10020 (94.99%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.154150
# After training
#
# Test set in round36: Average loss: 0.1679, Accuracy: 9507/10020 (94.88%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.185248
# After training
#
# Test set in round37: Average loss: 0.1686, Accuracy: 9499/10020 (94.80%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.131605
# After training
#
# Test set in round38: Average loss: 0.1655, Accuracy: 9528/10020 (95.09%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.172195
# After training
#
# Test set in round39: Average loss: 0.1631, Accuracy: 9517/10020 (94.98%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.196894
# After training
#
# Test set in round40: Average loss: 0.1619, Accuracy: 9534/10020 (95.15%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.138037
# After training
#
# Test set in round41: Average loss: 0.1512, Accuracy: 9559/10020 (95.40%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.129692
# After training
#
# Test set in round42: Average loss: 0.1526, Accuracy: 9547/10020 (95.28%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.123150
# After training
#
# Test set in round43: Average loss: 0.1503, Accuracy: 9558/10020 (95.39%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.071024
# After training
#
# Test set in round44: Average loss: 0.1459, Accuracy: 9567/10020 (95.48%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.182803
# After training
#
# Test set in round45: Average loss: 0.1496, Accuracy: 9549/10020 (95.30%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.125088
# After training
#
# Test set in round46: Average loss: 0.1417, Accuracy: 9595/10020 (95.76%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.110713
# After training
#
# Test set in round47: Average loss: 0.1366, Accuracy: 9610/10020 (95.91%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.154975
# After training
#
# Test set in round48: Average loss: 0.1338, Accuracy: 9617/10020 (95.98%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.114265
# After training
#
# Test set in round49: Average loss: 0.1339, Accuracy: 9614/10020 (95.95%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.176633
# After training
#
# Test set in round50: Average loss: 0.1421, Accuracy: 9561/10020 (95.42%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.106466
# After training
#
# Test set in round51: Average loss: 0.1330, Accuracy: 9616/10020 (95.97%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.083001
# After training
#
# Test set in round52: Average loss: 0.1270, Accuracy: 9626/10020 (96.07%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.106692
# After training
#
# Test set in round53: Average loss: 0.1269, Accuracy: 9621/10020 (96.02%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.161969
# After training
#
# Test set in round54: Average loss: 0.1254, Accuracy: 9621/10020 (96.02%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.126180
# After training
#
# Test set in round55: Average loss: 0.1192, Accuracy: 9648/10020 (96.29%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.132871
# After training
#
# Test set in round56: Average loss: 0.1230, Accuracy: 9627/10020 (96.08%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.046885
# After training
#
# Test set in round57: Average loss: 0.1205, Accuracy: 9633/10020 (96.14%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.119780
# After training
#
# Test set in round58: Average loss: 0.1176, Accuracy: 9656/10020 (96.37%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.127356
# After training
#
# Test set in round59: Average loss: 0.1166, Accuracy: 9661/10020 (96.42%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.153128
# After training
#
# Test set in round60: Average loss: 0.1154, Accuracy: 9658/10020 (96.39%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.147386
# After training
#
# Test set in round61: Average loss: 0.1130, Accuracy: 9676/10020 (96.57%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.045831
# After training
#
# Test set in round62: Average loss: 0.1117, Accuracy: 9666/10020 (96.47%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.129423
# After training
#
# Test set in round63: Average loss: 0.1123, Accuracy: 9675/10020 (96.56%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.064723
# After training
#
# Test set in round64: Average loss: 0.1090, Accuracy: 9677/10020 (96.58%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.045309
# After training
#
# Test set in round65: Average loss: 0.1114, Accuracy: 9672/10020 (96.53%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.113562
# After training
#
# Test set in round66: Average loss: 0.1078, Accuracy: 9667/10020 (96.48%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.116668
# After training
#
# Test set in round67: Average loss: 0.1070, Accuracy: 9678/10020 (96.59%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.104900
# After training
#
# Test set in round68: Average loss: 0.1044, Accuracy: 9681/10020 (96.62%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.062277
# After training
#
# Test set in round69: Average loss: 0.1006, Accuracy: 9706/10020 (96.87%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.149090
# After training
#
# Test set in round70: Average loss: 0.1035, Accuracy: 9704/10020 (96.85%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.099325
# After training
#
# Test set in round71: Average loss: 0.0986, Accuracy: 9707/10020 (96.88%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.083197
# After training
#
# Test set in round72: Average loss: 0.1002, Accuracy: 9701/10020 (96.82%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.127762
# After training
#
# Test set in round73: Average loss: 0.1019, Accuracy: 9692/10020 (96.73%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.034409
# After training
#
# Test set in round74: Average loss: 0.0974, Accuracy: 9697/10020 (96.78%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.137651
# After training
#
# Test set in round75: Average loss: 0.1015, Accuracy: 9692/10020 (96.73%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.085111
# After training
#
# Test set in round76: Average loss: 0.0942, Accuracy: 9728/10020 (97.09%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.121681
# After training
#
# Test set in round77: Average loss: 0.1014, Accuracy: 9691/10020 (96.72%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.032583
# After training
#
# Test set in round78: Average loss: 0.0926, Accuracy: 9716/10020 (96.97%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.075959
# After training
#
# Test set in round79: Average loss: 0.0912, Accuracy: 9724/10020 (97.05%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.140988
# After training
#
# Test set in round80: Average loss: 0.0966, Accuracy: 9704/10020 (96.85%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.082440
# After training
#
# Test set in round81: Average loss: 0.0933, Accuracy: 9726/10020 (97.07%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.074101
# After training
#
# Test set in round82: Average loss: 0.0896, Accuracy: 9732/10020 (97.13%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.151664
# After training
#
# Test set in round83: Average loss: 0.0874, Accuracy: 9735/10020 (97.16%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.086700
# After training
#
# Test set in round84: Average loss: 0.0871, Accuracy: 9735/10020 (97.16%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.075257
# After training
#
# Test set in round85: Average loss: 0.0874, Accuracy: 9725/10020 (97.06%)
#
# Train Epoch: 0 [6000/6000 (0%)]	Loss: 0.078784
# After training
#
# Test set in round86: Average loss: 0.0856, Accuracy: 9748/10020 (97.29%)
