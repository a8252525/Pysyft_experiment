# %%
# Use centrailzed training to compare with federated learning
epochs = 30
n_train_items = 12800

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torchvision import datasets, transforms
import numpy as np

# import torchcsprng as csprng

# %%
torch.cuda.is_available()
# Out:
# True

# %%
class Arguments():
    def __init__(self):
        self.batch_size = 250
        self.test_batch_size = 64
        self.epochs = epochs
        self.lr = 0.25
        self.momentum = 0.5
        self.no_cuda = False
        self.seed = 1
        self.log_interval = 30
        self.save_model = False

args = Arguments()

use_cuda = not args.no_cuda and torch.cuda.is_available()

torch.manual_seed(args.seed)

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}

# random_number_generator = csprng.create_random_device_generator(
#                 "/dev/urandom")

# %%
train_dataloader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=True, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.batch_size
)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=False, download=True, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=args.test_batch_size
)

    
#---

# train_dataloader = [
#         ((data), (target))
#         for i, (data, target) in enumerate(train_loader)
#         if i < n_train_items / args.batch_size
#     ]


# test_dataloader = [
#         ((data), (target))
#         for i, (data, target) in enumerate(test_loader)
#         if i < n_train_items / args.batch_size
#     ]

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, 8, 2, padding=3)
        self.conv2 = nn.Conv2d(16, 32, 4, 2)
        self.fc1 = nn.Linear(32 * 4 * 4, 32)
        self.fc2 = nn.Linear(32, 10)

    def forward(self, x):
        # x of shape [B, 1, 28, 28]
        x = F.relu(self.conv1(x))  # -> [B, 16, 14, 14]
        x = F.max_pool2d(x, 2, 1)  # -> [B, 16, 13, 13]
        x = F.relu(self.conv2(x))  # -> [B, 32, 5, 5]
        x = F.max_pool2d(x, 2, 1)  # -> [B, 32, 4, 4]
        x = x.view(-1, 32 * 4 * 4)  # -> [B, 512]
        x = F.relu(self.fc1(x))  # -> [B, 32]
        x = self.fc2(x)  # -> [B, 10]
        return x

    def name(self):
        return "SampleConvNet"

# %%
def train(args, device, model, train_dataloader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_dataloader):
        data,target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(),1.5)
        optimizer.step()
        
        
        if batch_idx % args.log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * args.batch_size, len(train_dataloader) * args.batch_size,
                100. * batch_idx / len(train_dataloader), loss.item()))

# %%
def test(args, device, model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():

            
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(1, keepdim=True) # get the index of the max log-probability 
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader)*(args.test_batch_size)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader)* (args.test_batch_size),
        100. * correct / (len(test_loader)*args.test_batch_size)))

# %%
#%%time
model = Net().to(device)
optimizer =  optim.SGD(model.parameters(), lr=args.lr)
for epoch in range(1, args.epochs + 1):
    train(args, device, model, train_dataloader, optimizer, epoch)
    test(args, device, model, test_loader)

if (args.save_model):
    torch.save(model.state_dict(), "mnist_cnn.pt")
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.305859
# Train Epoch: 1 [7500/60000 (12%)]	Loss: 1.200093
# Train Epoch: 1 [15000/60000 (25%)]	Loss: 0.433472
# Train Epoch: 1 [22500/60000 (38%)]	Loss: 0.306971
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 0.320085
# Train Epoch: 1 [37500/60000 (62%)]	Loss: 0.262745
# Train Epoch: 1 [45000/60000 (75%)]	Loss: 0.100497
# Train Epoch: 1 [52500/60000 (88%)]	Loss: 0.135185
#
# Test set: Average loss: 0.1272, Accuracy: 9582/10048 (95%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.138571
# Train Epoch: 2 [7500/60000 (12%)]	Loss: 0.051707
# Train Epoch: 2 [15000/60000 (25%)]	Loss: 0.034164
# Train Epoch: 2 [22500/60000 (38%)]	Loss: 0.082236
# Train Epoch: 2 [30000/60000 (50%)]	Loss: 0.065674
# Train Epoch: 2 [37500/60000 (62%)]	Loss: 0.082930
# Train Epoch: 2 [45000/60000 (75%)]	Loss: 0.054917
# Train Epoch: 2 [52500/60000 (88%)]	Loss: 0.069729
#
# Test set: Average loss: 0.0522, Accuracy: 9818/10048 (98%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.067855
# Train Epoch: 3 [7500/60000 (12%)]	Loss: 0.028458
# Train Epoch: 3 [15000/60000 (25%)]	Loss: 0.034154
# Train Epoch: 3 [22500/60000 (38%)]	Loss: 0.034982
# Train Epoch: 3 [30000/60000 (50%)]	Loss: 0.051636
# Train Epoch: 3 [37500/60000 (62%)]	Loss: 0.063427
# Train Epoch: 3 [45000/60000 (75%)]	Loss: 0.040766
# Train Epoch: 3 [52500/60000 (88%)]	Loss: 0.032380
#
# Test set: Average loss: 0.0419, Accuracy: 9865/10048 (98%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.057389
# Train Epoch: 4 [7500/60000 (12%)]	Loss: 0.021376
# Train Epoch: 4 [15000/60000 (25%)]	Loss: 0.024613
# Train Epoch: 4 [22500/60000 (38%)]	Loss: 0.029787
# Train Epoch: 4 [30000/60000 (50%)]	Loss: 0.042438
# Train Epoch: 4 [37500/60000 (62%)]	Loss: 0.048037
# Train Epoch: 4 [45000/60000 (75%)]	Loss: 0.030206
# Train Epoch: 4 [52500/60000 (88%)]	Loss: 0.024372
#
# Test set: Average loss: 0.0408, Accuracy: 9873/10048 (98%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.045851
# Train Epoch: 5 [7500/60000 (12%)]	Loss: 0.014841
# Train Epoch: 5 [15000/60000 (25%)]	Loss: 0.022783
# Train Epoch: 5 [22500/60000 (38%)]	Loss: 0.020391
# Train Epoch: 5 [30000/60000 (50%)]	Loss: 0.043367
# Train Epoch: 5 [37500/60000 (62%)]	Loss: 0.038459
# Train Epoch: 5 [45000/60000 (75%)]	Loss: 0.022775
# Train Epoch: 5 [52500/60000 (88%)]	Loss: 0.019345
#
# Test set: Average loss: 0.0376, Accuracy: 9877/10048 (98%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.036928
# Train Epoch: 6 [7500/60000 (12%)]	Loss: 0.009451
# Train Epoch: 6 [15000/60000 (25%)]	Loss: 0.018970
# Train Epoch: 6 [22500/60000 (38%)]	Loss: 0.023231
# Train Epoch: 6 [30000/60000 (50%)]	Loss: 0.044623
# Train Epoch: 6 [37500/60000 (62%)]	Loss: 0.031315
# Train Epoch: 6 [45000/60000 (75%)]	Loss: 0.019062
# Train Epoch: 6 [52500/60000 (88%)]	Loss: 0.020466
#
# Test set: Average loss: 0.0370, Accuracy: 9880/10048 (98%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.035520
# Train Epoch: 7 [7500/60000 (12%)]	Loss: 0.009225
# Train Epoch: 7 [15000/60000 (25%)]	Loss: 0.010824
# Train Epoch: 7 [22500/60000 (38%)]	Loss: 0.014668
# Train Epoch: 7 [30000/60000 (50%)]	Loss: 0.041368
# Train Epoch: 7 [37500/60000 (62%)]	Loss: 0.019145
# Train Epoch: 7 [45000/60000 (75%)]	Loss: 0.017107
# Train Epoch: 7 [52500/60000 (88%)]	Loss: 0.017120
#
# Test set: Average loss: 0.0343, Accuracy: 9886/10048 (98%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.022677
# Train Epoch: 8 [7500/60000 (12%)]	Loss: 0.004824
# Train Epoch: 8 [15000/60000 (25%)]	Loss: 0.011626
# Train Epoch: 8 [22500/60000 (38%)]	Loss: 0.020973
# Train Epoch: 8 [30000/60000 (50%)]	Loss: 0.038319
# Train Epoch: 8 [37500/60000 (62%)]	Loss: 0.021030
# Train Epoch: 8 [45000/60000 (75%)]	Loss: 0.005549
# Train Epoch: 8 [52500/60000 (88%)]	Loss: 0.014594
#
# Test set: Average loss: 0.0351, Accuracy: 9883/10048 (98%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.023425
# Train Epoch: 9 [7500/60000 (12%)]	Loss: 0.004690
# Train Epoch: 9 [15000/60000 (25%)]	Loss: 0.004143
# Train Epoch: 9 [22500/60000 (38%)]	Loss: 0.009983
# Train Epoch: 9 [30000/60000 (50%)]	Loss: 0.035878
# Train Epoch: 9 [37500/60000 (62%)]	Loss: 0.010563
# Train Epoch: 9 [45000/60000 (75%)]	Loss: 0.002548
# Train Epoch: 9 [52500/60000 (88%)]	Loss: 0.010857
#
# Test set: Average loss: 0.0377, Accuracy: 9885/10048 (98%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.018441
# Train Epoch: 10 [7500/60000 (12%)]	Loss: 0.002916
# Train Epoch: 10 [15000/60000 (25%)]	Loss: 0.005771
# Train Epoch: 10 [22500/60000 (38%)]	Loss: 0.025300
# Train Epoch: 10 [30000/60000 (50%)]	Loss: 0.035637
# Train Epoch: 10 [37500/60000 (62%)]	Loss: 0.013817
# Train Epoch: 10 [45000/60000 (75%)]	Loss: 0.004709
# Train Epoch: 10 [52500/60000 (88%)]	Loss: 0.011897
#
# Test set: Average loss: 0.0379, Accuracy: 9888/10048 (98%)
#
# Train Epoch: 11 [0/60000 (0%)]	Loss: 0.015746
# Train Epoch: 11 [7500/60000 (12%)]	Loss: 0.003428
# Train Epoch: 11 [15000/60000 (25%)]	Loss: 0.002650
# Train Epoch: 11 [22500/60000 (38%)]	Loss: 0.017087
# Train Epoch: 11 [30000/60000 (50%)]	Loss: 0.018368
# Train Epoch: 11 [37500/60000 (62%)]	Loss: 0.007720
# Train Epoch: 11 [45000/60000 (75%)]	Loss: 0.009402
# Train Epoch: 11 [52500/60000 (88%)]	Loss: 0.009502
#
# Test set: Average loss: 0.0546, Accuracy: 9843/10048 (98%)
#
# Train Epoch: 12 [0/60000 (0%)]	Loss: 0.026388
# Train Epoch: 12 [7500/60000 (12%)]	Loss: 0.001643
# Train Epoch: 12 [15000/60000 (25%)]	Loss: 0.001846
# Train Epoch: 12 [22500/60000 (38%)]	Loss: 0.015870
# Train Epoch: 12 [30000/60000 (50%)]	Loss: 0.038347
# Train Epoch: 12 [37500/60000 (62%)]	Loss: 0.003058
# Train Epoch: 12 [45000/60000 (75%)]	Loss: 0.004034
# Train Epoch: 12 [52500/60000 (88%)]	Loss: 0.007850
#
# Test set: Average loss: 0.0430, Accuracy: 9884/10048 (98%)
#
# Train Epoch: 13 [0/60000 (0%)]	Loss: 0.011528
# Train Epoch: 13 [7500/60000 (12%)]	Loss: 0.004388
# Train Epoch: 13 [15000/60000 (25%)]	Loss: 0.005608
# Train Epoch: 13 [22500/60000 (38%)]	Loss: 0.007672
# Train Epoch: 13 [30000/60000 (50%)]	Loss: 0.012980
# Train Epoch: 13 [37500/60000 (62%)]	Loss: 0.005806
# Train Epoch: 13 [45000/60000 (75%)]	Loss: 0.002680
# Train Epoch: 13 [52500/60000 (88%)]	Loss: 0.002638
#
# Test set: Average loss: 0.0458, Accuracy: 9884/10048 (98%)
#
# Train Epoch: 14 [0/60000 (0%)]	Loss: 0.009853
# Train Epoch: 14 [7500/60000 (12%)]	Loss: 0.001608
# Train Epoch: 14 [15000/60000 (25%)]	Loss: 0.002398
# Train Epoch: 14 [22500/60000 (38%)]	Loss: 0.006568
# Train Epoch: 14 [30000/60000 (50%)]	Loss: 0.004755
# Train Epoch: 14 [37500/60000 (62%)]	Loss: 0.010420
# Train Epoch: 14 [45000/60000 (75%)]	Loss: 0.003454
# Train Epoch: 14 [52500/60000 (88%)]	Loss: 0.001862
#
# Test set: Average loss: 0.0422, Accuracy: 9893/10048 (98%)
#
# Train Epoch: 15 [0/60000 (0%)]	Loss: 0.007931
# Train Epoch: 15 [7500/60000 (12%)]	Loss: 0.005753
# Train Epoch: 15 [15000/60000 (25%)]	Loss: 0.002142
# Train Epoch: 15 [22500/60000 (38%)]	Loss: 0.010104
# Train Epoch: 15 [30000/60000 (50%)]	Loss: 0.004621
# Train Epoch: 15 [37500/60000 (62%)]	Loss: 0.001814
# Train Epoch: 15 [45000/60000 (75%)]	Loss: 0.002754
# Train Epoch: 15 [52500/60000 (88%)]	Loss: 0.007981
#
# Test set: Average loss: 0.0610, Accuracy: 9851/10048 (98%)
#
# Train Epoch: 16 [0/60000 (0%)]	Loss: 0.013441
# Train Epoch: 16 [7500/60000 (12%)]	Loss: 0.006593
# Train Epoch: 16 [15000/60000 (25%)]	Loss: 0.001238
# Train Epoch: 16 [22500/60000 (38%)]	Loss: 0.006998
# Train Epoch: 16 [30000/60000 (50%)]	Loss: 0.005653
# Train Epoch: 16 [37500/60000 (62%)]	Loss: 0.004948
# Train Epoch: 16 [45000/60000 (75%)]	Loss: 0.010210
# Train Epoch: 16 [52500/60000 (88%)]	Loss: 0.003213
#
# Test set: Average loss: 0.0452, Accuracy: 9891/10048 (98%)
#
# Train Epoch: 17 [0/60000 (0%)]	Loss: 0.004837
# Train Epoch: 17 [7500/60000 (12%)]	Loss: 0.001596
# Train Epoch: 17 [15000/60000 (25%)]	Loss: 0.002750
# Train Epoch: 17 [22500/60000 (38%)]	Loss: 0.004870
# Train Epoch: 17 [30000/60000 (50%)]	Loss: 0.005347
# Train Epoch: 17 [37500/60000 (62%)]	Loss: 0.004503
# Train Epoch: 17 [45000/60000 (75%)]	Loss: 0.001632
# Train Epoch: 17 [52500/60000 (88%)]	Loss: 0.003300
#
# Test set: Average loss: 0.0420, Accuracy: 9895/10048 (98%)
#
# Train Epoch: 18 [0/60000 (0%)]	Loss: 0.010608
# Train Epoch: 18 [7500/60000 (12%)]	Loss: 0.001560
# Train Epoch: 18 [15000/60000 (25%)]	Loss: 0.001525
# Train Epoch: 18 [22500/60000 (38%)]	Loss: 0.004325
# Train Epoch: 18 [30000/60000 (50%)]	Loss: 0.003269
# Train Epoch: 18 [37500/60000 (62%)]	Loss: 0.001097
# Train Epoch: 18 [45000/60000 (75%)]	Loss: 0.002337
# Train Epoch: 18 [52500/60000 (88%)]	Loss: 0.001380
#
# Test set: Average loss: 0.0475, Accuracy: 9894/10048 (98%)
#
# Train Epoch: 19 [0/60000 (0%)]	Loss: 0.002016
# Train Epoch: 19 [7500/60000 (12%)]	Loss: 0.001015
# Train Epoch: 19 [15000/60000 (25%)]	Loss: 0.003261
# Train Epoch: 19 [22500/60000 (38%)]	Loss: 0.001353
# Train Epoch: 19 [30000/60000 (50%)]	Loss: 0.001364
# Train Epoch: 19 [37500/60000 (62%)]	Loss: 0.002079
# Train Epoch: 19 [45000/60000 (75%)]	Loss: 0.003674
# Train Epoch: 19 [52500/60000 (88%)]	Loss: 0.000614
#
# Test set: Average loss: 0.0480, Accuracy: 9897/10048 (98%)
#
# Train Epoch: 20 [0/60000 (0%)]	Loss: 0.001569
# Train Epoch: 20 [7500/60000 (12%)]	Loss: 0.001416
# Train Epoch: 20 [15000/60000 (25%)]	Loss: 0.000427
# Train Epoch: 20 [22500/60000 (38%)]	Loss: 0.001872
# Train Epoch: 20 [30000/60000 (50%)]	Loss: 0.000910
# Train Epoch: 20 [37500/60000 (62%)]	Loss: 0.002418
# Train Epoch: 20 [45000/60000 (75%)]	Loss: 0.000418
# Train Epoch: 20 [52500/60000 (88%)]	Loss: 0.002650
#
# Test set: Average loss: 0.0600, Accuracy: 9872/10048 (98%)
#
# Train Epoch: 21 [0/60000 (0%)]	Loss: 0.005170
# Train Epoch: 21 [7500/60000 (12%)]	Loss: 0.004244
# Train Epoch: 21 [15000/60000 (25%)]	Loss: 0.001316
# Train Epoch: 21 [22500/60000 (38%)]	Loss: 0.003532
# Train Epoch: 21 [30000/60000 (50%)]	Loss: 0.000581
# Train Epoch: 21 [37500/60000 (62%)]	Loss: 0.002149
# Train Epoch: 21 [45000/60000 (75%)]	Loss: 0.000555
# Train Epoch: 21 [52500/60000 (88%)]	Loss: 0.002345
#
# Test set: Average loss: 0.0550, Accuracy: 9887/10048 (98%)
#
# Train Epoch: 22 [0/60000 (0%)]	Loss: 0.001471
# Train Epoch: 22 [7500/60000 (12%)]	Loss: 0.001179
# Train Epoch: 22 [15000/60000 (25%)]	Loss: 0.000660
# Train Epoch: 22 [22500/60000 (38%)]	Loss: 0.002464
# Train Epoch: 22 [30000/60000 (50%)]	Loss: 0.000317
# Train Epoch: 22 [37500/60000 (62%)]	Loss: 0.001787
# Train Epoch: 22 [45000/60000 (75%)]	Loss: 0.001528
# Train Epoch: 22 [52500/60000 (88%)]	Loss: 0.000254
#
# Test set: Average loss: 0.0593, Accuracy: 9880/10048 (98%)
#
# Train Epoch: 23 [0/60000 (0%)]	Loss: 0.001725
# Train Epoch: 23 [7500/60000 (12%)]	Loss: 0.000235
# Train Epoch: 23 [15000/60000 (25%)]	Loss: 0.000387
# Train Epoch: 23 [22500/60000 (38%)]	Loss: 0.000723
# Train Epoch: 23 [30000/60000 (50%)]	Loss: 0.001697
# Train Epoch: 23 [37500/60000 (62%)]	Loss: 0.002761
# Train Epoch: 23 [45000/60000 (75%)]	Loss: 0.004819
# Train Epoch: 23 [52500/60000 (88%)]	Loss: 0.001785
#
# Test set: Average loss: 0.0577, Accuracy: 9894/10048 (98%)
#
# Train Epoch: 24 [0/60000 (0%)]	Loss: 0.002838
# Train Epoch: 24 [7500/60000 (12%)]	Loss: 0.000569
# Train Epoch: 24 [15000/60000 (25%)]	Loss: 0.001710
# Train Epoch: 24 [22500/60000 (38%)]	Loss: 0.002067
# Train Epoch: 24 [30000/60000 (50%)]	Loss: 0.003022
# Train Epoch: 24 [37500/60000 (62%)]	Loss: 0.001203
# Train Epoch: 24 [45000/60000 (75%)]	Loss: 0.000253
# Train Epoch: 24 [52500/60000 (88%)]	Loss: 0.000692
#
# Test set: Average loss: 0.0596, Accuracy: 9887/10048 (98%)
#
# Train Epoch: 25 [0/60000 (0%)]	Loss: 0.004262
# Train Epoch: 25 [7500/60000 (12%)]	Loss: 0.001258
# Train Epoch: 25 [15000/60000 (25%)]	Loss: 0.000078
# Train Epoch: 25 [22500/60000 (38%)]	Loss: 0.000636
# Train Epoch: 25 [30000/60000 (50%)]	Loss: 0.001435
# Train Epoch: 25 [37500/60000 (62%)]	Loss: 0.021009
# Train Epoch: 25 [45000/60000 (75%)]	Loss: 0.002314
# Train Epoch: 25 [52500/60000 (88%)]	Loss: 0.000698
#
# Test set: Average loss: 0.0561, Accuracy: 9889/10048 (98%)
#
# Train Epoch: 26 [0/60000 (0%)]	Loss: 0.003204
# Train Epoch: 26 [7500/60000 (12%)]	Loss: 0.001636
# Train Epoch: 26 [15000/60000 (25%)]	Loss: 0.021010
# Train Epoch: 26 [22500/60000 (38%)]	Loss: 0.006816
# Train Epoch: 26 [30000/60000 (50%)]	Loss: 0.007683
# Train Epoch: 26 [37500/60000 (62%)]	Loss: 0.000925
# Train Epoch: 26 [45000/60000 (75%)]	Loss: 0.006010
# Train Epoch: 26 [52500/60000 (88%)]	Loss: 0.004735
#
# Test set: Average loss: 0.0780, Accuracy: 9863/10048 (98%)
#
# Train Epoch: 27 [0/60000 (0%)]	Loss: 0.007285
# Train Epoch: 27 [7500/60000 (12%)]	Loss: 0.020762
# Train Epoch: 27 [15000/60000 (25%)]	Loss: 0.002214
# Train Epoch: 27 [22500/60000 (38%)]	Loss: 0.001408
# Train Epoch: 27 [30000/60000 (50%)]	Loss: 0.000574
# Train Epoch: 27 [37500/60000 (62%)]	Loss: 0.002820
# Train Epoch: 27 [45000/60000 (75%)]	Loss: 0.009292
# Train Epoch: 27 [52500/60000 (88%)]	Loss: 0.000208
#
# Test set: Average loss: 0.0551, Accuracy: 9903/10048 (99%)
#
# Train Epoch: 28 [0/60000 (0%)]	Loss: 0.002951
# Train Epoch: 28 [7500/60000 (12%)]	Loss: 0.000140
# Train Epoch: 28 [15000/60000 (25%)]	Loss: 0.000213
# Train Epoch: 28 [22500/60000 (38%)]	Loss: 0.001585
# Train Epoch: 28 [30000/60000 (50%)]	Loss: 0.000487
# Train Epoch: 28 [37500/60000 (62%)]	Loss: 0.006476
# Train Epoch: 28 [45000/60000 (75%)]	Loss: 0.006446
# Train Epoch: 28 [52500/60000 (88%)]	Loss: 0.000237
#
# Test set: Average loss: 0.0697, Accuracy: 9868/10048 (98%)
#
# Train Epoch: 29 [0/60000 (0%)]	Loss: 0.011332
# Train Epoch: 29 [7500/60000 (12%)]	Loss: 0.000491
# Train Epoch: 29 [15000/60000 (25%)]	Loss: 0.001370
# Train Epoch: 29 [22500/60000 (38%)]	Loss: 0.001064
# Train Epoch: 29 [30000/60000 (50%)]	Loss: 0.006243
# Train Epoch: 29 [37500/60000 (62%)]	Loss: 0.009659
# Train Epoch: 29 [45000/60000 (75%)]	Loss: 0.000039
# Train Epoch: 29 [52500/60000 (88%)]	Loss: 0.000418
#
# Test set: Average loss: 0.0580, Accuracy: 9893/10048 (98%)
#
# Train Epoch: 30 [0/60000 (0%)]	Loss: 0.004676
# Train Epoch: 30 [7500/60000 (12%)]	Loss: 0.005477
# Train Epoch: 30 [15000/60000 (25%)]	Loss: 0.011827
# Train Epoch: 30 [22500/60000 (38%)]	Loss: 0.001013
# Train Epoch: 30 [30000/60000 (50%)]	Loss: 0.000207
# Train Epoch: 30 [37500/60000 (62%)]	Loss: 0.011953
# Train Epoch: 30 [45000/60000 (75%)]	Loss: 0.003101
# Train Epoch: 30 [52500/60000 (88%)]	Loss: 0.005746
#
# Test set: Average loss: 0.0616, Accuracy: 9886/10048 (98%)
